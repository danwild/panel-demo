# %% [markdown]
# # Interactive Plot
#
# Move our logic to a python module

# %%
import panel as pn
import numpy as np
import pandas as pd
import param
from panel_plot import get_controls, get_plot

pn.extension()

# %%
pn.Row(get_controls(), get_plot())
# Out:
# Row
#     [0] Column
#         [0] FloatSlider(end=6.283185307179586, name='Phase', value=2.2)
#         [1] FloatSlider(end=5, name='Frequency', value=1.5)
#     [1] Column
#         [0] Bokeh(Figure)
#         [1] ParamFunction(function)
