# %% [markdown]
# # My Bokeh Plot
#
# Based on: https://panel.holoviz.org/reference/panes/Bokeh.html#panes-gallery-bokeh

# %%
import numpy as np
from bokeh.plotting import figure, show, output_notebook
from bokeh.layouts import column, row
from bokeh.models import ColumnDataSource, Slider, TextInput
output_notebook()

# DO SCIENCE THINGS
N = 200
x = np.linspace(0, 4*np.pi, N)
y = np.sin(x)
source = ColumnDataSource(data=dict(x=x, y=y))

# DO PLOT
plot = figure(
    plot_height=400, 
    plot_width=400, 
    title="Dan's amazing sine wave",
    tools="hover,crosshair,pan,reset,save,wheel_zoom",
    x_range=[0, 4*np.pi], 
    y_range=[-2.5, 2.5]
)
plot.line('x', 'y', source=source, line_width=3, line_alpha=0.6)

# AMAZE ME
show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1002">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="134cb115-da10-4408-bc67-60906868ea66" data-root-id="1004"></div>
